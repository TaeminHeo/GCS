# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import matlab.engine
eng = matlab.engine.start_matlab()

#greedy copula segmentation
def GCS(x,copula_family,lbd):
    K = 1
    seg = []
    seg.append(x)
    while K > 0:
        print(K)
        LL_all = np.zeros((K,len(x)))
        for j in range(K):
            n = len(seg[j])
            LL_segorig = LL(seg[j],copula_family,lbd)
            for k in range(2,n-3):
                print(k,end='\r')
                LL_all[j,k] = LL(seg[j][:k,:],copula_family,lbd) + LL(seg[j][k:,:],copula_family,lbd) - LL_segorig
            if K == 1:
                LL_all_1 = LL_all
            elif K == 2:
                LL_all_2 = LL_all

        if np.max(LL_all) > 0:
            j_star, k_star = np.where(LL_all == np.max(LL_all))
            if j_star.item() == (K-1):
                seg.append(seg[K-1][k_star.item()+1:,:])
                seg[K-1] = seg[K-1][:k_star.item()+1,:]
                K = K + 1
            else:
                K = -1
        else:
            K = -1
    return seg, LL_all_1, LL_all_2

def LL(x,copula_family,lbd):
    #marginal distribution fitting
    pd1 = st.gamma.fit(x[:,0])
    dist1 = st.gamma(a=pd1[0],loc=pd1[1],scale=pd1[2])
    cdf1 = dist1.cdf(x[:,0])
    var1 = np.var(x[:,0])

    pd2 = st.lognorm.fit(x[:,1])
    dist2 = st.lognorm(s=pd2[0],loc=pd2[1],scale=pd2[2])
    cdf2 = dist2.cdf(x[:,1])
    var2 = np.var(x[:,1])

    #copula fitting
    cdfs = eng.transpose(matlab.double([cdf1,cdf2]))
    copula_paramhat = eng.copulafit(copula_family, cdfs)

    #loglikelihood
    loglikelihood = eng.sum(eng.log(eng.copulapdf(copula_family,cdfs,copula_paramhat))) - lbd / (var1 + var2)

    return loglikelihood

def LL_v2(seg,k,pre,copula_family,lbd):
    if pre == True:
        x = seg[:k]
    else:
        x = seg[k:]
        
    #marginal distribution fitting
    pd1 = st.gamma.fit(x[:,0])
    dist1 = st.gamma(a=pd1[0],loc=pd1[1],scale=pd1[2])
    cdf1 = dist1.cdf(x[:,0])
    var1 = np.var(x[:,0])

    pd2 = st.lognorm.fit(x[:,1])
    dist2 = st.lognorm(s=pd2[0],loc=pd2[1],scale=pd2[2])
    cdf2 = dist2.cdf(x[:,1])
    var2 = np.var(x[:,1])

    #copula fitting
    cdfs = eng.transpose(matlab.double([cdf1,cdf2]))
    copula_paramhat = eng.copulafit(copula_family, cdfs)

    #loglikelihood
    loglikelihood = eng.sum(eng.log(eng.copulapdf(copula_family,cdfs,copula_paramhat))) - lbd / (var1 + var2)

    return loglikelihood

# %%
df = pd.read_table('../../data/Benchmark/toyproblem.csv', sep = ',')

# %%
x = np.array(df)
copula_family = 'Clayton'
lbd = 100

# %%
# %%time
results = GCS(x,copula_family,lbd)
# Out:
# 1
# 2
# CPU times: total: 7min 13s
# Wall time: 7min 46s

# %%
fig, ax = plt.subplots(3,1)
ax[0].plot(results[1].T)
ax[1].plot(results[2][0].T)
ax[2].plot(results[2][1].T)
plt.show()

# %%
plt.hist(df.iloc[:300,0],density=True)
param = st.gamma.fit(df.iloc[:300,0])
tmp = np.linspace(gamma.ppf(0.01, param[0], param[1], param[2]),gamma.ppf(0.99, param[0], param[1], param[2]), 100)
plt.plot(tmp, gamma.pdf(tmp, param[0], param[1], param[2]),'r-', lw=5, alpha=0.6, label='gamma pdf')
plt.plot(tmp, gamma.pdf(tmp, 11.1771, scale=0.433858),'k--', lw=5, alpha=0.6, label='gamma pdf')
plt.show()

print('MATLAB:',np.sum(np.log(gamma.pdf(df.iloc[:300,0], 11.1771, scale=0.433858))))
print('PYTHON:',np.sum(np.log(gamma.pdf(df.iloc[:300,0], param[0], param[1], param[2]))))
# Out:
# MATLAB: -528.1018543556036
# PYTHON: -527.920056657028

# %%
mhws = pd.read_table('../../data/mhw/mhw_2017_train.csv', sep = ',')

# %%
plt.hist(mhws.iloc[:20,0],density=True)
param = st.gamma.fit(mhws.iloc[:20,0])
tmp = np.linspace(gamma.ppf(0.2, param[0], param[1], param[2]),gamma.ppf(0.8, param[0], param[1], param[2]), 100)
plt.plot(tmp, gamma.pdf(tmp, param[0], param[1], param[2]),'r-', lw=5, alpha=0.6, label='gamma pdf')
plt.plot(tmp, gamma.pdf(tmp, 7.57697, scale=1.02284),'k--', lw=5, alpha=0.6, label='gamma pdf')
plt.show()

print('MATLAB:',np.sum(np.log(gamma.pdf(mhws.iloc[:20,0], 7.57697, scale=1.02284))))
print('PYTHON:',np.sum(np.log(gamma.pdf(mhws.iloc[:20,0], param[0], param[1], param[2]))))
# Out:
# MATLAB: -48.17214801262411
# PYTHON: 14.760189522800225

# %%
param
# Out:
# (0.5072537558296257, 4.999999999999999, 1.8830093221990847)
