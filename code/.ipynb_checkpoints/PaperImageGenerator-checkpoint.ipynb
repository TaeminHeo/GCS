# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from scipy.integrate import simps

plt.rcParams.update({'font.size': 14})

# %%
df = pd.read_csv('../data/data.csv')

# %%
df.head()
# Out:
#          date  precipitation  temperature        PET    spi_g3    spi_g6  \
# 0  1896-12-01      43.650390    10.250000  15.436143 -0.513807  0.497865
# 1  1897-01-01      44.330080     5.750000   4.602221 -0.584178  0.429545
# 2  1897-02-01       4.200195    12.500000  23.140656 -0.680471  0.335547
# 3  1897-03-01      90.549805    16.950195  52.992420 -0.107730 -0.513281
# 4  1897-04-01      60.980470    19.049805  71.035450 -0.244276 -0.693784
#
#     spi_g12   spi_g24    spi_p3    spi_p6  ...  spei_g24   spei_p3   spei_p6  \
# 0 -0.152487  0.056428 -0.579120  0.449710  ...  0.122127 -0.459720  0.345873
# 1 -0.370692  0.096466 -0.745716  0.378167  ...  0.178179 -0.601604  0.389101
# 2 -0.781599 -0.133654 -0.704154  0.254527  ... -0.084828 -0.614268  0.307477
# 3 -0.476656  0.109161 -0.138778 -0.556821  ...  0.079721 -0.222051 -0.494931
# 4 -0.742530  0.086133 -0.278683 -0.734773  ...  0.065095 -0.420828 -0.681043
#
#    spei_p12  spei_p24      pdsi      phdi      pmdi    scpdsi    zindex
# 0 -0.438963  0.006990 -2.829379 -2.742514 -2.299250 -2.742514  0.962748
# 1 -0.614058  0.060894 -2.567383 -2.489243 -2.027468 -2.489243 -0.087623
# 2 -0.905177 -0.174819 -2.983024 -2.907807 -2.907807 -2.907807 -2.024869
# 3 -0.746047  0.010565 -2.210590 -2.028139 -1.248526 -2.028139  1.740493
# 4 -0.931860  0.006835 -2.189406 -2.024192 -1.453848 -2.024192 -0.614854
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(14,2.5))
plt.plot(df['spei_g3'],'k')
plt.ylabel('SPEI_G3')
plt.xticks([37,37+240,37+240*2,37+240*3,37+240*4,37+240*5,37+240*6],
           [1900,1920,1940,1960,1980,2000,2020])
plt.show()

# %%
alldata = pd.read_csv('../data/alldata.csv',header=None)

# %%
#base 20 updat 10
plt.figure(figsize=(14,2.5))
plt.plot(alldata[0],alldata[1],'k',marker='.')
plt.ylabel('Duration (months)')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.fill(np.concatenate([[0,27], [27,0]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[37,52], [52,37]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[64,77], [77,64]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[87,94], [94,87]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[105,115], [115,105]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[128,143], [143,128]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.show()

# %%
#base 20 updat 10
plt.figure(figsize=(14,2.5))
plt.plot(alldata[0],alldata[2],'k',marker='.')
plt.xlabel('Years from data origin (12/01/1896)')
plt.ylabel('Severity')
plt.xticks([27,37,52,64,77,87,94,105,115,128],
           [20,30,40,50,60,70,80,90,100,110])
plt.fill(np.concatenate([[0,28], [28,0]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[38,52], [52,38]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[64,77], [77,64]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[87,94], [94,87]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[105,115], [115,105]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.fill(np.concatenate([[128,143], [143,128]]),
                 np.concatenate([[0,0],[20,20]]),
                 alpha=.25, fc='grey', ec='None')
plt.show()
