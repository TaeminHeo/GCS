# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/toyproblem.csv',header=None)

# %%
plt.figure(figsize=[10,2])
plt.plot(data.iloc[:,0],'k')
plt.ylabel('x1')
plt.show()

# %%
plt.figure(figsize=[10,2])
plt.plot(data.iloc[:,1],'k')
plt.xlabel('samples')
plt.ylabel('x2')
plt.show()
